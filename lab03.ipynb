# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
# Load the data
images_1 = np.load('data/images0.npy')
images_2 = np.load('data/images.npy')

# Examine the shape of the data
print("========= DATASET 1 =========")
print(f"Number of images: {images_1.shape[0]}")
print(f"Image shape: {images_1.shape[1:]}")

print("========= DATASET 2 =========")
print(f"Number of images: {images_2.shape[0]}")
print(f"Image shape: {images_2.shape[1:]}")
# Out:
# ========= DATASET 1 =========
# Number of images: 1000
# Image shape: (100, 100)
# ========= DATASET 2 =========
# Number of images: 1000
# Image shape: (100, 100)

# %%
from utils import visualize_image

# Visualize a random image from each dataset
visualize_image(images_1[np.random.randint(0, images_1.shape[0])])
visualize_image(images_2[np.random.randint(0, images_2.shape[0])])

# %%
from utils import average_image

avg_image_1 = average_image(images_1)
avg_image_2 = average_image(images_2)

# Visualize the average images
visualize_image(avg_image_1)
visualize_image(avg_image_2)

# %% [markdown]
# ## Task 1

# %%
from utils import maximize_likelihood

# Estimate the parameters of the first dataset
s, eta = maximize_likelihood(avg_image_1)

visualize_image(s)
print(f"Eta: {eta}")
# Out:
# Number of ones in s:  4959
# Number of zeros in s:  5041
# Number of ones in s:  211
# Number of zeros in s:  9789
# Number of ones in s:  2811
# Number of zeros in s:  7189
# Number of ones in s:  2831
# Number of zeros in s:  7169
# Eta: [0, 0.40659410651221534]
